# %% [markdown]
# <a href="https://colab.research.google.com/github/hana-an/Image-quality-metrics/blob/main/docs/examples/model_energy_U_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Energy estimation of U-Net model.
#
# Unet shows reduction in total energy per inference (GPU) and reduction in storage requirements.

# %%
# !pip install keras_spiking

# %%
import warnings

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.callbacks import TensorBoard

import keras_spiking

warnings.simplefilter("ignore")
tf.get_logger().addFilter(lambda rec: "Tracing is expensive" not in rec.msg)

# %% [markdown]
# ## Using ModelEnergy
#
# The ``keras_spiking.ModelEnergy`` class provides the entry point for energy estimation.
# It takes a Keras model as input, and computes relevant statistics for that model.

# %% [markdown]
# unet

# %%
num_classes = 1

inputs = tf.keras.layers.Input((128,128,3))

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
b1 = tf.keras.layers.BatchNormalization()(c1)
r1 = tf.keras.layers.ReLU()(b1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(r1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
b2 = tf.keras.layers.BatchNormalization()(c2)
r2 = tf.keras.layers.ReLU()(b2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(r2)

c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
b3 = tf.keras.layers.BatchNormalization()(c3)
r3 = tf.keras.layers.ReLU()(b3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(r3)

c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
b4 = tf.keras.layers.BatchNormalization()(c4)
r4 = tf.keras.layers.ReLU()(b4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(r4)

c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
b5 = tf.keras.layers.BatchNormalization()(c5)
r5 = tf.keras.layers.ReLU()(b5)
c5 = tf.keras.layers.Dropout(0.3)(r5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
u6 = tf.keras.layers.BatchNormalization()(u6)
u6 = tf.keras.layers.ReLU()(u6)


u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(u6)
u7 = tf.keras.layers.concatenate([u7, c3])
u7 = tf.keras.layers.BatchNormalization()(u7)
u7 = tf.keras.layers.ReLU()(u7)


u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(u7)
u8 = tf.keras.layers.concatenate([u8, c2])
u8 = tf.keras.layers.BatchNormalization()(u8)
u8 = tf.keras.layers.ReLU()(u8)

u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(u8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
u9 = tf.keras.layers.BatchNormalization()(u9)
u9 = tf.keras.layers.ReLU()(u9)


outputs = tf.keras.layers.Conv2D(num_classes, (1, 1), activation='sigmoid')(u9)
model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 16)         448       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 128, 128, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)         2320      ['dropout[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 16)         64        ['conv2d_1[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 128, 128, 16)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)           0         ['re_lu[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)           4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)           0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)           9248      ['dropout_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 64, 32)           128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 64, 64, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)           0         ['re_lu_1[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)           36928     ['dropout_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 32, 32, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)           0         ['re_lu_2[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)          147584    ['dropout_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 16, 16, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 128)            0         ['re_lu_3[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)            295168    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)            1024      ['conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 8, 8, 256)            0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 8, 8, 256)            0         ['re_lu_4[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)            590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  batch_normalization_5 (Bat  (None, 16, 16, 256)          1024      ['concatenate[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 16, 16, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 64)           65600     ['re_lu_5[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 128)          512       ['concatenate_1[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 32, 32, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 32)           16416     ['re_lu_6[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 64)           0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 64, 64, 64)           256       ['concatenate_2[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 64, 64, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 16)         4112      ['re_lu_7[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 128, 128, 32)         128       ['concatenate_3[0][0]']
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 128, 128, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 1)          33        ['re_lu_8[0][0]']
#
# ==================================================================================================
# Total params: 1400033 (5.34 MB)
# Trainable params: 1398081 (5.33 MB)
# Non-trainable params: 1952 (7.62 KB)
# __________________________________________________________________________________________________

# %%
# estimate model energy
energy = keras_spiking.ModelEnergy(model)
energy.summary(print_warnings=False)
# Out:
# Layer (type)                           |Output shape        |Param #|Conn #  |Neuron #|J/inf (cpu)
# ---------------------------------------|--------------------|-------|--------|--------|-----------
# input_1 (InputLayer)                   |[(None, 128, 128, 3)|      0|       0|       0|          0
# conv2d (Conv2D)                        |(None, 128, 128, 16)|    448| 7077888|  262144|      0.063
# dropout (Dropout)                      |(None, 128, 128, 16)|      0|       0|       0|          0
# conv2d_1 (Conv2D)                      |(None, 128, 128, 16)|   2320|37748736|  262144|       0.33
# batch_normalization (BatchNormalization|(None, 128, 128, 16)|     64|       0|       0|          0
# re_lu (ReLU)                           |(None, 128, 128, 16)|      0|       0|  262144|     0.0023
# max_pooling2d (MaxPooling2D)           |  (None, 64, 64, 16)|      0|       0|       0|          0
# conv2d_2 (Conv2D)                      |  (None, 64, 64, 32)|   4640|18874368|  131072|       0.16
# dropout_1 (Dropout)                    |  (None, 64, 64, 32)|      0|       0|       0|          0
# conv2d_3 (Conv2D)                      |  (None, 64, 64, 32)|   9248|37748736|  131072|       0.33
# batch_normalization_1 (BatchNormalizati|  (None, 64, 64, 32)|    128|       0|       0|          0
# re_lu_1 (ReLU)                         |  (None, 64, 64, 32)|      0|       0|  131072|     0.0011
# max_pooling2d_1 (MaxPooling2D)         |  (None, 32, 32, 32)|      0|       0|       0|          0
# conv2d_4 (Conv2D)                      |  (None, 32, 32, 64)|  18496|18874368|   65536|       0.16
# dropout_2 (Dropout)                    |  (None, 32, 32, 64)|      0|       0|       0|          0
# conv2d_5 (Conv2D)                      |  (None, 32, 32, 64)|  36928|37748736|   65536|       0.33
# batch_normalization_2 (BatchNormalizati|  (None, 32, 32, 64)|    256|       0|       0|          0
# re_lu_2 (ReLU)                         |  (None, 32, 32, 64)|      0|       0|   65536|    0.00056
# max_pooling2d_2 (MaxPooling2D)         |  (None, 16, 16, 64)|      0|       0|       0|          0
# conv2d_6 (Conv2D)                      | (None, 16, 16, 128)|  73856|18874368|   32768|       0.16
# dropout_3 (Dropout)                    | (None, 16, 16, 128)|      0|       0|       0|          0
# conv2d_7 (Conv2D)                      | (None, 16, 16, 128)| 147584|37748736|   32768|       0.32
# batch_normalization_3 (BatchNormalizati| (None, 16, 16, 128)|    512|       0|       0|          0
# re_lu_3 (ReLU)                         | (None, 16, 16, 128)|      0|       0|   32768|    0.00028
# max_pooling2d_3 (MaxPooling2D)         |   (None, 8, 8, 128)|      0|       0|       0|          0
# conv2d_8 (Conv2D)                      |   (None, 8, 8, 256)| 295168|18874368|   16384|       0.16
# batch_normalization_4 (BatchNormalizati|   (None, 8, 8, 256)|   1024|       0|       0|          0
# re_lu_4 (ReLU)                         |   (None, 8, 8, 256)|      0|       0|   16384|    0.00014
# dropout_4 (Dropout)                    |   (None, 8, 8, 256)|      0|       0|       0|          0
# conv2d_9 (Conv2D)                      |   (None, 8, 8, 256)| 590080|37748736|   16384|       0.32
# conv2d_transpose (Conv2DTranspose)     | (None, 16, 16, 128)| 131200|16777216|       0|       0.14
# concatenate (Concatenate)              | (None, 16, 16, 256)|      0|       0|       0|          0
# batch_normalization_5 (BatchNormalizati| (None, 16, 16, 256)|   1024|       0|       0|          0
# re_lu_5 (ReLU)                         | (None, 16, 16, 256)|      0|       0|   65536|    0.00056
# conv2d_transpose_1 (Conv2DTranspose)   |  (None, 32, 32, 64)|  65600|16777216|       0|       0.14
# concatenate_1 (Concatenate)            | (None, 32, 32, 128)|      0|       0|       0|          0
# batch_normalization_6 (BatchNormalizati| (None, 32, 32, 128)|    512|       0|       0|          0
# re_lu_6 (ReLU)                         | (None, 32, 32, 128)|      0|       0|  131072|     0.0011
# conv2d_transpose_2 (Conv2DTranspose)   |  (None, 64, 64, 32)|  16416|16777216|       0|       0.14
# concatenate_2 (Concatenate)            |  (None, 64, 64, 64)|      0|       0|       0|          0
# batch_normalization_7 (BatchNormalizati|  (None, 64, 64, 64)|    256|       0|       0|          0
# re_lu_7 (ReLU)                         |  (None, 64, 64, 64)|      0|       0|  262144|     0.0023
# conv2d_transpose_3 (Conv2DTranspose)   |(None, 128, 128, 16)|   4112|16777216|       0|       0.14
# concatenate_3 (Concatenate)            |(None, 128, 128, 32)|      0|       0|       0|          0
# batch_normalization_8 (BatchNormalizati|(None, 128, 128, 32)|    128|       0|       0|          0
# re_lu_8 (ReLU)                         |(None, 128, 128, 32)|      0|       0|  524288|     0.0045
# conv2d_10 (Conv2D)                     | (None, 128, 128, 1)|     33|  524288|   16384|     0.0046
# ==================================================================================================
# Total energy per inference [Joules/inf] (cpu): 2.94e+00

# %%
energy.summary(
    columns=(
        "name",
        "energy cpu",
        "energy gpu",
        "synop_energy cpu",
        "synop_energy gpu",
        "neuron_energy cpu",
        "neuron_energy gpu",
    ),
    print_warnings=False,
)
# Out:
# Layer (type)      |J/inf (cpu)|J/inf (gpu)|Synop J/inf (|Synop J/inf (|Neuron J/inf |Neuron J/inf
# ------------------|-----------|-----------|-------------|-------------|-------------|-------------
# input_1 (InputLaye|          0|          0|            0|            0|            0|            0
# conv2d (Conv2D)   |      0.063|     0.0022|        0.061|       0.0021|       0.0023|      7.9e-05
# dropout (Dropout) |          0|          0|            0|            0|            0|            0
# conv2d_1 (Conv2D) |       0.33|      0.011|         0.32|        0.011|       0.0023|      7.9e-05
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu (ReLU)      |     0.0023|    7.9e-05|            0|            0|       0.0023|      7.9e-05
# max_pooling2d (Max|          0|          0|            0|            0|            0|            0
# conv2d_2 (Conv2D) |       0.16|     0.0057|         0.16|       0.0057|       0.0011|      3.9e-05
# dropout_1 (Dropout|          0|          0|            0|            0|            0|            0
# conv2d_3 (Conv2D) |       0.33|      0.011|         0.32|        0.011|       0.0011|      3.9e-05
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_1 (ReLU)    |     0.0011|    3.9e-05|            0|            0|       0.0011|      3.9e-05
# max_pooling2d_1 (M|          0|          0|            0|            0|            0|            0
# conv2d_4 (Conv2D) |       0.16|     0.0057|         0.16|       0.0057|      0.00056|        2e-05
# dropout_2 (Dropout|          0|          0|            0|            0|            0|            0
# conv2d_5 (Conv2D) |       0.33|      0.011|         0.32|        0.011|      0.00056|        2e-05
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_2 (ReLU)    |    0.00056|      2e-05|            0|            0|      0.00056|        2e-05
# max_pooling2d_2 (M|          0|          0|            0|            0|            0|            0
# conv2d_6 (Conv2D) |       0.16|     0.0057|         0.16|       0.0057|      0.00028|      9.8e-06
# dropout_3 (Dropout|          0|          0|            0|            0|            0|            0
# conv2d_7 (Conv2D) |       0.32|      0.011|         0.32|        0.011|      0.00028|      9.8e-06
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_3 (ReLU)    |    0.00028|    9.8e-06|            0|            0|      0.00028|      9.8e-06
# max_pooling2d_3 (M|          0|          0|            0|            0|            0|            0
# conv2d_8 (Conv2D) |       0.16|     0.0057|         0.16|       0.0057|      0.00014|      4.9e-06
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_4 (ReLU)    |    0.00014|    4.9e-06|            0|            0|      0.00014|      4.9e-06
# dropout_4 (Dropout|          0|          0|            0|            0|            0|            0
# conv2d_9 (Conv2D) |       0.32|      0.011|         0.32|        0.011|      0.00014|      4.9e-06
# conv2d_transpose (|       0.14|      0.005|         0.14|        0.005|            0|            0
# concatenate (Conca|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_5 (ReLU)    |    0.00056|      2e-05|            0|            0|      0.00056|        2e-05
# conv2d_transpose_1|       0.14|      0.005|         0.14|        0.005|            0|            0
# concatenate_1 (Con|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_6 (ReLU)    |     0.0011|    3.9e-05|            0|            0|       0.0011|      3.9e-05
# conv2d_transpose_2|       0.14|      0.005|         0.14|        0.005|            0|            0
# concatenate_2 (Con|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_7 (ReLU)    |     0.0023|    7.9e-05|            0|            0|       0.0023|      7.9e-05
# conv2d_transpose_3|       0.14|      0.005|         0.14|        0.005|            0|            0
# concatenate_3 (Con|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_8 (ReLU)    |     0.0045|    0.00016|            0|            0|       0.0045|      0.00016
# conv2d_10 (Conv2D)|     0.0046|    0.00016|       0.0045|      0.00016|      0.00014|      4.9e-06
# ==================================================================================================
# Total energy per inference [Joules/inf] (cpu): 2.94e+00
# Total energy per inference [Joules/inf] (gpu): 1.02e-01

# %% [markdown]
# lcrm unet

# %%
num_classes = 1

inputs = tf.keras.layers.Input((128,128,3))

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=1,kernel_size=3,strides=(1,1),padding='same')(c1)
#c1= #tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
b1 = tf.keras.layers.BatchNormalization()(c1)
r1 = tf.keras.layers.ReLU()(b1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(r1)

c2 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=2,kernel_size=3,strides=(1,1),padding='same')(p1)
#c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=1,kernel_size=3,strides=(1,1),padding='same')(c2)
#c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
b2 = tf.keras.layers.BatchNormalization()(c2)
r2 = tf.keras.layers.ReLU()(b2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(r2)

c3 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=2,kernel_size=3,strides=(1,1),padding='same')(p2)
#c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)

c3 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=1,kernel_size=3,strides=(1,1),padding='same')(c3)
#c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
b3 = tf.keras.layers.BatchNormalization()(c3)
r3 = tf.keras.layers.ReLU()(b3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(r3)

c3 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=2,kernel_size=3,strides=(1,1),padding='same')(p2)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)

c4 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=1,kernel_size=3,strides=(1,1),padding='same')(c4)
#c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
b4 = tf.keras.layers.BatchNormalization()(c4)
r4 = tf.keras.layers.ReLU()(b4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(r4)

c5 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=2,kernel_size=3,strides=(1,1),padding='same')(p4)
#c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
b5 = tf.keras.layers.BatchNormalization()(c5)
r5 = tf.keras.layers.ReLU()(b5)
c5 = tf.keras.layers.Dropout(0.3)(r5)
c5 = tf.keras.layers.DepthwiseConv2D(depth_multiplier=1,kernel_size=3,strides=(1,1),padding='same')(c5)
#c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
u6 = tf.keras.layers.BatchNormalization()(u6)
u6 = tf.keras.layers.ReLU()(u6)


u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(u6)
u7 = tf.keras.layers.concatenate([u7, c3])
u7 = tf.keras.layers.BatchNormalization()(u7)
u7 = tf.keras.layers.ReLU()(u7)


u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(u7)
u8 = tf.keras.layers.concatenate([u8, c2])
u8 = tf.keras.layers.BatchNormalization()(u8)
u8 = tf.keras.layers.ReLU()(u8)

u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(u8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
u9 = tf.keras.layers.BatchNormalization()(u9)
u9 = tf.keras.layers.ReLU()(u9)


outputs = tf.keras.layers.Conv2D(num_classes, (1, 1), activation='sigmoid')(u9)
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 16)         448       ['input_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 16)         0         ['conv2d_11[0][0]']
#
#  depthwise_conv2d (Depthwis  (None, 128, 128, 16)         160       ['dropout_5[0][0]']
#  eConv2D)
#
#  batch_normalization_9 (Bat  (None, 128, 128, 16)         64        ['depthwise_conv2d[0][0]']
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 128, 128, 16)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  max_pooling2d_4 (MaxPoolin  (None, 64, 64, 16)           0         ['re_lu_9[0][0]']
#  g2D)
#
#  depthwise_conv2d_1 (Depthw  (None, 64, 64, 32)           320       ['max_pooling2d_4[0][0]']
#  iseConv2D)
#
#  dropout_6 (Dropout)         (None, 64, 64, 32)           0         ['depthwise_conv2d_1[0][0]']
#
#  depthwise_conv2d_2 (Depthw  (None, 64, 64, 32)           320       ['dropout_6[0][0]']
#  iseConv2D)
#
#  batch_normalization_10 (Ba  (None, 64, 64, 32)           128       ['depthwise_conv2d_2[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 64, 64, 32)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 32, 32)           0         ['re_lu_10[0][0]']
#  g2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 32, 32, 64)           640       ['max_pooling2d_5[0][0]']
#  iseConv2D)
#
#  dropout_7 (Dropout)         (None, 32, 32, 64)           0         ['depthwise_conv2d_3[0][0]']
#
#  depthwise_conv2d_4 (Depthw  (None, 32, 32, 64)           640       ['dropout_7[0][0]']
#  iseConv2D)
#
#  batch_normalization_11 (Ba  (None, 32, 32, 64)           256       ['depthwise_conv2d_4[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 32, 32, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 64)           0         ['re_lu_11[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 128)          73856     ['max_pooling2d_6[0][0]']
#
#  dropout_8 (Dropout)         (None, 16, 16, 128)          0         ['conv2d_12[0][0]']
#
#  depthwise_conv2d_6 (Depthw  (None, 16, 16, 128)          1280      ['dropout_8[0][0]']
#  iseConv2D)
#
#  batch_normalization_12 (Ba  (None, 16, 16, 128)          512       ['depthwise_conv2d_6[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 16, 16, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 128)            0         ['re_lu_12[0][0]']
#  g2D)
#
#  depthwise_conv2d_7 (Depthw  (None, 8, 8, 256)            2560      ['max_pooling2d_7[0][0]']
#  iseConv2D)
#
#  batch_normalization_13 (Ba  (None, 8, 8, 256)            1024      ['depthwise_conv2d_7[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 8, 8, 256)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 8, 8, 256)            0         ['re_lu_13[0][0]']
#
#  depthwise_conv2d_8 (Depthw  (None, 8, 8, 256)            2560      ['dropout_9[0][0]']
#  iseConv2D)
#
#  conv2d_transpose_4 (Conv2D  (None, 16, 16, 128)          131200    ['depthwise_conv2d_8[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 16, 16, 256)          0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'depthwise_conv2d_6[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 256)          1024      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 16, 16, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_transpose_5 (Conv2D  (None, 32, 32, 64)           65600     ['re_lu_14[0][0]']
#  Transpose)
#
#  depthwise_conv2d_5 (Depthw  (None, 32, 32, 64)           640       ['max_pooling2d_5[0][0]']
#  iseConv2D)
#
#  concatenate_5 (Concatenate  (None, 32, 32, 128)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'depthwise_conv2d_5[0][0]']
#
#  batch_normalization_15 (Ba  (None, 32, 32, 128)          512       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 32, 32, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_transpose_6 (Conv2D  (None, 64, 64, 32)           16416     ['re_lu_15[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 64, 64, 64)           0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'depthwise_conv2d_2[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 64)           256       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 64, 64, 64)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_transpose_7 (Conv2D  (None, 128, 128, 16)         4112      ['re_lu_16[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 128, 128, 32)         0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'depthwise_conv2d[0][0]']
#
#  batch_normalization_17 (Ba  (None, 128, 128, 32)         128       ['concatenate_7[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 128, 128, 32)         0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 1)          33        ['re_lu_17[0][0]']
#
# ==================================================================================================
# Total params: 304689 (1.16 MB)
# Trainable params: 302737 (1.15 MB)
# Non-trainable params: 1952 (7.62 KB)
# __________________________________________________________________________________________________

# %%
# estimate model energy
energy = keras_spiking.ModelEnergy(model)
energy.summary(print_warnings=False)
# Out:
# Layer (type)                           |Output shape        |Param #|Conn #  |Neuron #|J/inf (cpu)
# ---------------------------------------|--------------------|-------|--------|--------|-----------
# input_2 (InputLayer)                   |[(None, 128, 128, 3)|      0|       0|       0|          0
# conv2d_11 (Conv2D)                     |(None, 128, 128, 16)|    448| 7077888|  262144|      0.063
# dropout_5 (Dropout)                    |(None, 128, 128, 16)|      0|       0|       0|          0
# depthwise_conv2d (DepthwiseConv2D)     |(None, 128, 128, 16)|    160|       0|       0|          0
# batch_normalization_9 (BatchNormalizati|(None, 128, 128, 16)|     64|       0|       0|          0
# re_lu_9 (ReLU)                         |(None, 128, 128, 16)|      0|       0|  262144|     0.0023
# max_pooling2d_4 (MaxPooling2D)         |  (None, 64, 64, 16)|      0|       0|       0|          0
# depthwise_conv2d_1 (DepthwiseConv2D)   |  (None, 64, 64, 32)|    320|       0|       0|          0
# dropout_6 (Dropout)                    |  (None, 64, 64, 32)|      0|       0|       0|          0
# depthwise_conv2d_2 (DepthwiseConv2D)   |  (None, 64, 64, 32)|    320|       0|       0|          0
# batch_normalization_10 (BatchNormalizat|  (None, 64, 64, 32)|    128|       0|       0|          0
# re_lu_10 (ReLU)                        |  (None, 64, 64, 32)|      0|       0|  131072|     0.0011
# max_pooling2d_5 (MaxPooling2D)         |  (None, 32, 32, 32)|      0|       0|       0|          0
# depthwise_conv2d_3 (DepthwiseConv2D)   |  (None, 32, 32, 64)|    640|       0|       0|          0
# dropout_7 (Dropout)                    |  (None, 32, 32, 64)|      0|       0|       0|          0
# depthwise_conv2d_4 (DepthwiseConv2D)   |  (None, 32, 32, 64)|    640|       0|       0|          0
# batch_normalization_11 (BatchNormalizat|  (None, 32, 32, 64)|    256|       0|       0|          0
# re_lu_11 (ReLU)                        |  (None, 32, 32, 64)|      0|       0|   65536|    0.00056
# max_pooling2d_6 (MaxPooling2D)         |  (None, 16, 16, 64)|      0|       0|       0|          0
# conv2d_12 (Conv2D)                     | (None, 16, 16, 128)|  73856|18874368|   32768|       0.16
# dropout_8 (Dropout)                    | (None, 16, 16, 128)|      0|       0|       0|          0
# depthwise_conv2d_6 (DepthwiseConv2D)   | (None, 16, 16, 128)|   1280|       0|       0|          0
# batch_normalization_12 (BatchNormalizat| (None, 16, 16, 128)|    512|       0|       0|          0
# re_lu_12 (ReLU)                        | (None, 16, 16, 128)|      0|       0|   32768|    0.00028
# max_pooling2d_7 (MaxPooling2D)         |   (None, 8, 8, 128)|      0|       0|       0|          0
# depthwise_conv2d_7 (DepthwiseConv2D)   |   (None, 8, 8, 256)|   2560|       0|       0|          0
# batch_normalization_13 (BatchNormalizat|   (None, 8, 8, 256)|   1024|       0|       0|          0
# re_lu_13 (ReLU)                        |   (None, 8, 8, 256)|      0|       0|   16384|    0.00014
# dropout_9 (Dropout)                    |   (None, 8, 8, 256)|      0|       0|       0|          0
# depthwise_conv2d_8 (DepthwiseConv2D)   |   (None, 8, 8, 256)|   2560|       0|       0|          0
# conv2d_transpose_4 (Conv2DTranspose)   | (None, 16, 16, 128)| 131200|16777216|       0|       0.14
# concatenate_4 (Concatenate)            | (None, 16, 16, 256)|      0|       0|       0|          0
# batch_normalization_14 (BatchNormalizat| (None, 16, 16, 256)|   1024|       0|       0|          0
# re_lu_14 (ReLU)                        | (None, 16, 16, 256)|      0|       0|   65536|    0.00056
# conv2d_transpose_5 (Conv2DTranspose)   |  (None, 32, 32, 64)|  65600|16777216|       0|       0.14
# depthwise_conv2d_5 (DepthwiseConv2D)   |  (None, 32, 32, 64)|    640|       0|       0|          0
# concatenate_5 (Concatenate)            | (None, 32, 32, 128)|      0|       0|       0|          0
# batch_normalization_15 (BatchNormalizat| (None, 32, 32, 128)|    512|       0|       0|          0
# re_lu_15 (ReLU)                        | (None, 32, 32, 128)|      0|       0|  131072|     0.0011
# conv2d_transpose_6 (Conv2DTranspose)   |  (None, 64, 64, 32)|  16416|16777216|       0|       0.14
# concatenate_6 (Concatenate)            |  (None, 64, 64, 64)|      0|       0|       0|          0
# batch_normalization_16 (BatchNormalizat|  (None, 64, 64, 64)|    256|       0|       0|          0
# re_lu_16 (ReLU)                        |  (None, 64, 64, 64)|      0|       0|  262144|     0.0023
# conv2d_transpose_7 (Conv2DTranspose)   |(None, 128, 128, 16)|   4112|16777216|       0|       0.14
# concatenate_7 (Concatenate)            |(None, 128, 128, 32)|      0|       0|       0|          0
# batch_normalization_17 (BatchNormalizat|(None, 128, 128, 32)|    128|       0|       0|          0
# re_lu_17 (ReLU)                        |(None, 128, 128, 32)|      0|       0|  524288|     0.0045
# conv2d_13 (Conv2D)                     | (None, 128, 128, 1)|     33|  524288|   16384|     0.0046
# ==================================================================================================
# Total energy per inference [Joules/inf] (cpu): 8.20e-01

# %%
energy.summary(
    columns=(
        "name",
        "energy cpu",
        "energy gpu",
        "synop_energy cpu",
        "synop_energy gpu",
        "neuron_energy cpu",
        "neuron_energy gpu",
    ),
    print_warnings=False,
)
# Out:
# Layer (type)      |J/inf (cpu)|J/inf (gpu)|Synop J/inf (|Synop J/inf (|Neuron J/inf |Neuron J/inf
# ------------------|-----------|-----------|-------------|-------------|-------------|-------------
# input_2 (InputLaye|          0|          0|            0|            0|            0|            0
# conv2d_11 (Conv2D)|      0.063|     0.0022|        0.061|       0.0021|       0.0023|      7.9e-05
# dropout_5 (Dropout|          0|          0|            0|            0|            0|            0
# depthwise_conv2d (|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_9 (ReLU)    |     0.0023|    7.9e-05|            0|            0|       0.0023|      7.9e-05
# max_pooling2d_4 (M|          0|          0|            0|            0|            0|            0
# depthwise_conv2d_1|          0|          0|            0|            0|            0|            0
# dropout_6 (Dropout|          0|          0|            0|            0|            0|            0
# depthwise_conv2d_2|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_10 (ReLU)   |     0.0011|    3.9e-05|            0|            0|       0.0011|      3.9e-05
# max_pooling2d_5 (M|          0|          0|            0|            0|            0|            0
# depthwise_conv2d_3|          0|          0|            0|            0|            0|            0
# dropout_7 (Dropout|          0|          0|            0|            0|            0|            0
# depthwise_conv2d_4|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_11 (ReLU)   |    0.00056|      2e-05|            0|            0|      0.00056|        2e-05
# max_pooling2d_6 (M|          0|          0|            0|            0|            0|            0
# conv2d_12 (Conv2D)|       0.16|     0.0057|         0.16|       0.0057|      0.00028|      9.8e-06
# dropout_8 (Dropout|          0|          0|            0|            0|            0|            0
# depthwise_conv2d_6|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_12 (ReLU)   |    0.00028|    9.8e-06|            0|            0|      0.00028|      9.8e-06
# max_pooling2d_7 (M|          0|          0|            0|            0|            0|            0
# depthwise_conv2d_7|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_13 (ReLU)   |    0.00014|    4.9e-06|            0|            0|      0.00014|      4.9e-06
# dropout_9 (Dropout|          0|          0|            0|            0|            0|            0
# depthwise_conv2d_8|          0|          0|            0|            0|            0|            0
# conv2d_transpose_4|       0.14|      0.005|         0.14|        0.005|            0|            0
# concatenate_4 (Con|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_14 (ReLU)   |    0.00056|      2e-05|            0|            0|      0.00056|        2e-05
# conv2d_transpose_5|       0.14|      0.005|         0.14|        0.005|            0|            0
# depthwise_conv2d_5|          0|          0|            0|            0|            0|            0
# concatenate_5 (Con|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_15 (ReLU)   |     0.0011|    3.9e-05|            0|            0|       0.0011|      3.9e-05
# conv2d_transpose_6|       0.14|      0.005|         0.14|        0.005|            0|            0
# concatenate_6 (Con|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_16 (ReLU)   |     0.0023|    7.9e-05|            0|            0|       0.0023|      7.9e-05
# conv2d_transpose_7|       0.14|      0.005|         0.14|        0.005|            0|            0
# concatenate_7 (Con|          0|          0|            0|            0|            0|            0
# batch_normalizatio|          0|          0|            0|            0|            0|            0
# re_lu_17 (ReLU)   |     0.0045|    0.00016|            0|            0|       0.0045|      0.00016
# conv2d_13 (Conv2D)|     0.0046|    0.00016|       0.0045|      0.00016|      0.00014|      4.9e-06
# ==================================================================================================
# Total energy per inference [Joules/inf] (cpu): 8.20e-01
# Total energy per inference [Joules/inf] (gpu): 2.86e-02

# %% [markdown]
# # **Result Summary of LCRM (optimized) AlexNEt:**
# Total params: 7787658 (29.71 MB)
#
# Trainable params: 7784970 (29.70 MB)
#
# Non-trainable params: 2688 (10.50 KB)
#
# Total energy per inference [Joules/inf] (cpu): 8.15e-01
#
# Total energy per inference [Joules/inf] (gpu): 2.84e-02
#
# # **Result Summary of parent ALexNet model:**
# Total params: 14250762 (54.36 MB)
#
# Trainable params: 14248010 (54.35 MB)
#
# Non-trainable params: 2752 (10.75 KB)
#
# Total energy per inference [Joules/inf] (cpu): 9.35e+00
#
# Total energy per inference [Joules/inf] (gpu): 3.26e-01
#
#
#
# **Overall there is a 91.2 % reduction in total energy perinference (GPU) and 45.3 % reduction in storage requirement**
